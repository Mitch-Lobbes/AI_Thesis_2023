# %%
# Author: Mitchell D. Lobbes

# Standard imports
import pandas as pd
import numpy as np

# Plotting imports
import matplotlib.pyplot as plt

# Sklearn imports
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
import xgboost as xgb

# Imputation imports
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

# %%
# Set Viewing Options
pd.set_option('display.width', 5000)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

# %%
data = pd.read_csv("../../../Data/Model/Model_data_cleaned.csv") 
data
# Out:
#      rental_price     GLA  n_res_benefits  population  d_school  d_transfer  d_mainstreet  n_business  n_earners  d_supermarket  avg_income  %_single_family_homes  k20_high_income  households_with_children  single_households  household_size  k40_low_income    WOZ  n_owner_occupied  urbanity_score  supermarket_1km  k0_k15  k15_k25  k25_k45  k45_k65  k65+
# 0      145.000000   800.0           960.0        5710       0.3         1.8           1.6       965.0     4500.0            0.4        26.9                   22.0             15.5                       245               3385             1.3            51.8  253.0              24.0             1.0              8.3     255     2155     1830      840   620
# 1      113.000000  1000.0           390.0        2160       0.2         1.0           0.6       220.0     1700.0            0.4        26.5                    2.0             16.2                       165               1050             1.4            43.0  229.0              33.0             1.0              3.0     155      525      940      345   190
# 2      145.428980  1049.0           640.0        5975       0.3         2.9           1.2       550.0     5000.0            0.5        24.9                   14.0             15.6                       385               2855             1.4            50.7  226.0              30.0             1.0              4.7     455     2275     2110      745   380
# 3      195.647807  2280.0           640.0        5975       0.3         2.9           1.2       550.0     5000.0            0.5        24.9                   14.0             15.6                       385               2855             1.4            50.7  226.0              30.0             1.0              4.7     455     2275     2110      745   380
# 4      105.000000  1400.0             0.0         650       NaN         NaN           NaN       200.0        NaN            0.4         NaN                    0.0              NaN                        70                175             1.8             NaN  321.0              47.0             2.0              NaN      70       60      265      165    90
# ..            ...     ...             ...         ...       ...         ...           ...         ...        ...            ...         ...                    ...              ...                       ...                ...             ...             ...    ...               ...             ...              ...     ...      ...      ...      ...   ...
# 296    127.000000  1400.0             0.0        4410       NaN         NaN           NaN       395.0        NaN            0.6         NaN                   66.0              NaN                       820                435             2.6             NaN  334.0              66.0             3.0              NaN    1095      425     1395     1025   465
# 297    120.000000   833.0           780.0        3000       0.9        16.3           0.8       210.0     2400.0            0.4        25.9                   95.0             15.2                       485                400             2.2            38.9  239.0              71.0             4.0              1.0     510      315      740      820   620
# 298    170.000000  2045.0          1280.0        7095       0.7        16.2           1.6       550.0     5600.0            0.8        29.6                   77.0             22.4                      1215                860             2.4            33.2  299.0              72.0             3.0              0.8    1295      795     1965     2185   860
# 299    123.000000  1674.0             0.0        1875       NaN         NaN           NaN       270.0        NaN            0.5         NaN                   43.0              NaN                       150                560             1.7             NaN  238.0              47.0             3.0              NaN     150      170      435      445   685
# 300    163.000000  1874.0          1220.0        3950       0.3        25.3           1.3       330.0     3200.0            0.5        24.7                   85.0             12.9                       625                630             2.2            45.1  273.0              53.0             3.0              2.8     565      485      940     1095   865
#
# [301 rows x 26 columns]

# %%
X = data.drop(columns=["rental_price"], axis=1).copy()
y = data["rental_price"].copy()

imputer = IterativeImputer(random_state=42)
X = pd.DataFrame(imputer.fit_transform(X), columns=X.columns)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %%
def evaluate(model, test_features, test_labels):

    # calculate RMSE
    mse = mean_squared_error(test_labels, model.predict(test_features))
    rmse = np.sqrt(mse)
    print('RMSE: %.3f' % rmse)
    
    # calculate R^2
    r2 = r2_score(test_labels, model.predict(test_features))
    print('R^2: %.3f' % r2)

    # calculate mae
    mae = np.mean(abs(model.predict(test_features) - test_labels))
    print('MAE: %.3f' % mae)

    # calculate mape
    mape = np.mean(abs(model.predict(test_features) - test_labels) / test_labels)
    print('MAPE: %.3f' % mape)

    # calculate accuracy
    accuracy = 1 - mape
    print('Accuracy: %.3f' % accuracy)

# %%
reg_xgb = xgb.XGBRegressor(objective='reg:squarederror', missing=np.nan, seed=42)
reg_xgb.fit(X_train, y_train)
evaluate(reg_xgb, X_test, y_test)
# Out:
# RMSE: 35.298
# R^2: -0.181
# MAE: 25.954
# MAPE: 0.178
# Accuracy: 0.822

# %%
from sklearn.model_selection import RandomizedSearchCV

random_grid = {
 'n_estimators': [10,20, 50,100,200,300,400,500],
 "learning_rate" : [0.05,0.10,0.15,0.20,0.25,0.30],
 "max_depth" : [ 3, 4, 5, 6, 8, 10, 12, 15],
 "min_child_weight" : [ 1, 3, 5, 7 ],
 "gamma": [ 0.0, 0.1, 0.2 , 0.3, 0.4 ],
 "colsample_bytree" : [ 0.3, 0.4, 0.5 , 0.7 ],
 "reg_alpha": [0, 0.5, 1, 5],
 "reg_lambda": [0, 0.5, 1, 5]
}

# %%
xgbr = xgb.XGBRegressor(objective='reg:squarederror', missing=np.nan, seed=42)
xgbr_random = RandomizedSearchCV(estimator = xgbr, param_distributions = random_grid, n_iter = 30, cv = 10, verbose=2, random_state=42, n_jobs = -1)
xgbr_random.fit(X_train, y_train)
# Out:
# Fitting 10 folds for each of 30 candidates, totalling 300 fits
# [CV] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.3, max_depth=12, min_child_weight=1, n_estimators=400, reg_alpha=0.5, reg_lambda=1; total time=   0.8s
# [CV] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.3, max_depth=12, min_child_weight=1, n_estimators=400, reg_alpha=0.5, reg_lambda=1; total time=   0.8s
# [CV] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.3, max_depth=12, min_child_weight=1, n_estimators=400, reg_alpha=0.5, reg_lambda=1; total time=   0.8s
# [CV] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.3, max_depth=12, min_child_weight=1, n_estimators=400, reg_alpha=0.5, reg_lambda=1; total time=   0.8s
# [CV] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.3, max_depth=12, min_child_weight=1, n_estimators=400, reg_alpha=0.5, reg_lambda=1; total time=   0.8s
# [CV] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.3, max_depth=12, min_child_weight=1, n_estimators=400, reg_alpha=0.5, reg_lambda=1; total time=   0.8s
# [CV] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.3, max_depth=12, min_child_weight=1, n_estimators=400, reg_alpha=0.5, reg_lambda=1; total time=   0.8s
# [CV] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.3, max_depth=12, min_child_weight=1, n_estimators=400, reg_alpha=0.5, reg_lambda=1; total time=   0.8s
# [CV] END colsample_bytree=0.4, gamma=0.0, learning_rate=0.3, max_depth=12, min_child_weight=7, n_estimators=100, reg_alpha=0, reg_lambda=5; total time=   0.2s
# [CV] END colsample_bytree=0.4, gamma=0.0, learning_rate=0.3, max_depth=12, min_child_weight=7, n_estimators=100, reg_alpha=0, reg_lambda=5; total time=   0.2s
# [CV] END colsample_bytree=0.4, gamma=0.0, learning_rate=0.3, max_depth=12, min_child_weight=7, n_estimators=100, reg_alpha=0, reg_lambda=5; total time=   0.1s
# [CV] END colsample_bytree=0.4, gamma=0.0, learning_rate=0.3, max_depth=12, min_child_weight=7, n_estimators=100, reg_alpha=0, reg_lambda=5; total time=   0.2s
# [CV] END colsample_bytree=0.4, gamma=0.0, learning_rate=0.3, max_depth=12, min_child_weight=7, n_estimators=100, reg_alpha=0, reg_lambda=5; total time=   0.2s
# [CV] END colsample_bytree=0.4, gamma=0.0, learning_rate=0.3, max_depth=12, min_child_weight=7, n_estimators=100, reg_alpha=0, reg_lambda=5; total time=   0.2s
# [CV] END colsample_bytree=0.4, gamma=0.0, learning_rate=0.3, max_depth=12, min_child_weight=7, n_estimators=100, reg_alpha=0, reg_lambda=5; total time=   0.2s
# [CV] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.3, max_depth=12, min_child_weight=1, n_estimators=400, reg_alpha=0.5, reg_lambda=1; total time=   0.8s
# [CV] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.3, max_depth=12, min_child_weight=1, n_estimators=400, reg_alpha=0.5, reg_lambda=1; total time=   0.8s
# [CV] END colsample_bytree=0.4, gamma=0.0, learning_rate=0.3, max_depth=12, min_child_weight=7, n_estimators=100, reg_alpha=0, reg_lambda=5; total time=   0.2s
# [CV] END colsample_bytree=0.4, gamma=0.0, learning_rate=0.3, max_depth=12, min_child_weight=7, n_estimators=100, reg_alpha=0, reg_lambda=5; total time=   0.2s
# [CV] END colsample_bytree=0.4, gamma=0.0, learning_rate=0.3, max_depth=12, min_child_weight=7, n_estimators=100, reg_alpha=0, reg_lambda=5; total time=   0.2s
# [CV] END colsample_bytree=0.4, gamma=0.0, learning_rate=0.15, max_depth=4, min_child_weight=5, n_estimators=300, reg_alpha=5, reg_lambda=0; total time=   0.3s
# [CV] END colsample_bytree=0.4, gamma=0.0, learning_rate=0.15, max_depth=4, min_child_weight=5, n_estimators=300, reg_alpha=5, reg_lambda=0; total time=   0.3s
# [CV] END colsample_bytree=0.4, gamma=0.0, learning_rate=0.15, max_depth=4, min_child_weight=5, n_estimators=300, reg_alpha=5, reg_lambda=0; total time=   0.3s
# [CV] END colsample_bytree=0.4, gamma=0.0, learning_rate=0.15, max_depth=4, min_child_weight=5, n_estimators=300, reg_alpha=5, reg_lambda=0; total time=   0.3s
# [CV] END colsample_bytree=0.4, gamma=0.0, learning_rate=0.15, max_depth=4, min_child_weight=5, n_estimators=300, reg_alpha=5, reg_lambda=0; total time=   0.3s
# [CV] END colsample_bytree=0.4, gamma=0.0, learning_rate=0.15, max_depth=4, min_child_weight=5, n_estimators=300, reg_alpha=5, reg_lambda=0; total time=   0.3s
# [CV] END colsample_bytree=0.4, gamma=0.0, learning_rate=0.15, max_depth=4, min_child_weight=5, n_estimators=300, reg_alpha=5, reg_lambda=0; total time=   0.3s
# [CV] END colsample_bytree=0.4, gamma=0.0, learning_rate=0.15, max_depth=4, min_child_weight=5, n_estimators=300, reg_alpha=5, reg_lambda=0; total time=   0.3s
# [CV] END colsample_bytree=0.5, gamma=0.4, learning_rate=0.3, max_depth=5, min_child_weight=5, n_estimators=10, reg_alpha=5, reg_lambda=1; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=0.4, learning_rate=0.3, max_depth=5, min_child_weight=5, n_estimators=10, reg_alpha=5, reg_lambda=1; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=0.4, learning_rate=0.3, max_depth=5, min_child_weight=5, n_estimators=10, reg_alpha=5, reg_lambda=1; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=0.4, learning_rate=0.3, max_depth=5, min_child_weight=5, n_estimators=10, reg_alpha=5, reg_lambda=1; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=0.4, learning_rate=0.3, max_depth=5, min_child_weight=5, n_estimators=10, reg_alpha=5, reg_lambda=1; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=0.4, learning_rate=0.3, max_depth=5, min_child_weight=5, n_estimators=10, reg_alpha=5, reg_lambda=1; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=0.4, learning_rate=0.3, max_depth=5, min_child_weight=5, n_estimators=10, reg_alpha=5, reg_lambda=1; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=0.4, learning_rate=0.3, max_depth=5, min_child_weight=5, n_estimators=10, reg_alpha=5, reg_lambda=1; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=0.4, learning_rate=0.3, max_depth=5, min_child_weight=5, n_estimators=10, reg_alpha=5, reg_lambda=1; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=0.4, learning_rate=0.3, max_depth=5, min_child_weight=5, n_estimators=10, reg_alpha=5, reg_lambda=1; total time=   0.0s
# [CV] END colsample_bytree=0.4, gamma=0.0, learning_rate=0.15, max_depth=4, min_child_weight=5, n_estimators=300, reg_alpha=5, reg_lambda=0; total time=   0.3s
# [CV] END colsample_bytree=0.4, gamma=0.0, learning_rate=0.15, max_depth=4, min_child_weight=5, n_estimators=300, reg_alpha=5, reg_lambda=0; total time=   0.3s
# [CV] END colsample_bytree=0.5, gamma=0.0, learning_rate=0.2, max_depth=5, min_child_weight=1, n_estimators=400, reg_alpha=1, reg_lambda=1; total time=   0.4s
# [CV] END colsample_bytree=0.5, gamma=0.0, learning_rate=0.2, max_depth=5, min_child_weight=1, n_estimators=400, reg_alpha=1, reg_lambda=1; total time=   0.4s
# [CV] END colsample_bytree=0.5, gamma=0.0, learning_rate=0.2, max_depth=5, min_child_weight=1, n_estimators=400, reg_alpha=1, reg_lambda=1; total time=   0.4s
# [CV] END colsample_bytree=0.5, gamma=0.0, learning_rate=0.2, max_depth=5, min_child_weight=1, n_estimators=400, reg_alpha=1, reg_lambda=1; total time=   0.5s
# [CV] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.3, max_depth=5, min_child_weight=1, n_estimators=200, reg_alpha=0.5, reg_lambda=5; total time=   0.2s
# [CV] END colsample_bytree=0.5, gamma=0.0, learning_rate=0.2, max_depth=5, min_child_weight=1, n_estimators=400, reg_alpha=1, reg_lambda=1; total time=   0.4s
# [CV] END colsample_bytree=0.5, gamma=0.0, learning_rate=0.2, max_depth=5, min_child_weight=1, n_estimators=400, reg_alpha=1, reg_lambda=1; total time=   0.5s
# [CV] END colsample_bytree=0.5, gamma=0.0, learning_rate=0.2, max_depth=5, min_child_weight=1, n_estimators=400, reg_alpha=1, reg_lambda=1; total time=   0.4s
# [CV] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.3, max_depth=5, min_child_weight=1, n_estimators=200, reg_alpha=0.5, reg_lambda=5; total time=   0.2s
# [CV] END colsample_bytree=0.5, gamma=0.0, learning_rate=0.2, max_depth=5, min_child_weight=1, n_estimators=400, reg_alpha=1, reg_lambda=1; total time=   0.4s
# [CV] END colsample_bytree=0.5, gamma=0.0, learning_rate=0.2, max_depth=5, min_child_weight=1, n_estimators=400, reg_alpha=1, reg_lambda=1; total time=   0.4s
# [CV] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.3, max_depth=5, min_child_weight=1, n_estimators=200, reg_alpha=0.5, reg_lambda=5; total time=   0.3s
# [CV] END colsample_bytree=0.5, gamma=0.0, learning_rate=0.2, max_depth=5, min_child_weight=1, n_estimators=400, reg_alpha=1, reg_lambda=1; total time=   0.4s
# [CV] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.3, max_depth=5, min_child_weight=1, n_estimators=200, reg_alpha=0.5, reg_lambda=5; total time=   0.2s
# [CV] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.3, max_depth=5, min_child_weight=1, n_estimators=200, reg_alpha=0.5, reg_lambda=5; total time=   0.2s
# [CV] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.3, max_depth=5, min_child_weight=1, n_estimators=200, reg_alpha=0.5, reg_lambda=5; total time=   0.2s
# [CV] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.3, max_depth=5, min_child_weight=1, n_estimators=200, reg_alpha=0.5, reg_lambda=5; total time=   0.2s
# [CV] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.15, max_depth=15, min_child_weight=3, n_estimators=100, reg_alpha=5, reg_lambda=0; total time=   0.2s
# [CV] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.3, max_depth=5, min_child_weight=1, n_estimators=200, reg_alpha=0.5, reg_lambda=5; total time=   0.2s
# [CV] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.3, max_depth=5, min_child_weight=1, n_estimators=200, reg_alpha=0.5, reg_lambda=5; total time=   0.2s
# [CV] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.3, max_depth=5, min_child_weight=1, n_estimators=200, reg_alpha=0.5, reg_lambda=5; total time=   0.2s
# [CV] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.15, max_depth=15, min_child_weight=3, n_estimators=100, reg_alpha=5, reg_lambda=0; total time=   0.2s
# [CV] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.15, max_depth=15, min_child_weight=3, n_estimators=100, reg_alpha=5, reg_lambda=0; total time=   0.2s
# [CV] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.15, max_depth=15, min_child_weight=3, n_estimators=100, reg_alpha=5, reg_lambda=0; total time=   0.2s
# [CV] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.15, max_depth=15, min_child_weight=3, n_estimators=100, reg_alpha=5, reg_lambda=0; total time=   0.2s
# [CV] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.15, max_depth=15, min_child_weight=3, n_estimators=100, reg_alpha=5, reg_lambda=0; total time=   0.2s
# [CV] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.15, max_depth=15, min_child_weight=3, n_estimators=100, reg_alpha=5, reg_lambda=0; total time=   0.2s
# [CV] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.15, max_depth=15, min_child_weight=3, n_estimators=100, reg_alpha=5, reg_lambda=0; total time=   0.2s
# [CV] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.15, max_depth=15, min_child_weight=3, n_estimators=100, reg_alpha=5, reg_lambda=0; total time=   0.2s
# [CV] END colsample_bytree=0.4, gamma=0.3, learning_rate=0.15, max_depth=12, min_child_weight=1, n_estimators=20, reg_alpha=0.5, reg_lambda=0; total time=   0.1s
# [CV] END colsample_bytree=0.4, gamma=0.3, learning_rate=0.15, max_depth=12, min_child_weight=1, n_estimators=20, reg_alpha=0.5, reg_lambda=0; total time=   0.1s
# [CV] END colsample_bytree=0.4, gamma=0.3, learning_rate=0.15, max_depth=12, min_child_weight=1, n_estimators=20, reg_alpha=0.5, reg_lambda=0; total time=   0.1s
# [CV] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.15, max_depth=15, min_child_weight=3, n_estimators=100, reg_alpha=5, reg_lambda=0; total time=   0.2s
# [CV] END colsample_bytree=0.4, gamma=0.3, learning_rate=0.15, max_depth=12, min_child_weight=1, n_estimators=20, reg_alpha=0.5, reg_lambda=0; total time=   0.1s
# [CV] END colsample_bytree=0.4, gamma=0.3, learning_rate=0.15, max_depth=12, min_child_weight=1, n_estimators=20, reg_alpha=0.5, reg_lambda=0; total time=   0.1s
# [CV] END colsample_bytree=0.4, gamma=0.3, learning_rate=0.15, max_depth=12, min_child_weight=1, n_estimators=20, reg_alpha=0.5, reg_lambda=0; total time=   0.1s
# [CV] END colsample_bytree=0.4, gamma=0.3, learning_rate=0.15, max_depth=12, min_child_weight=1, n_estimators=20, reg_alpha=0.5, reg_lambda=0; total time=   0.0s
# [CV] END colsample_bytree=0.4, gamma=0.3, learning_rate=0.15, max_depth=12, min_child_weight=1, n_estimators=20, reg_alpha=0.5, reg_lambda=0; total time=   0.1s
# [CV] END colsample_bytree=0.4, gamma=0.3, learning_rate=0.15, max_depth=12, min_child_weight=1, n_estimators=20, reg_alpha=0.5, reg_lambda=0; total time=   0.1s
# [CV] END colsample_bytree=0.4, gamma=0.3, learning_rate=0.15, max_depth=12, min_child_weight=1, n_estimators=20, reg_alpha=0.5, reg_lambda=0; total time=   0.1s
# [CV] END colsample_bytree=0.3, gamma=0.2, learning_rate=0.1, max_depth=6, min_child_weight=1, n_estimators=400, reg_alpha=0.5, reg_lambda=1; total time=   0.5s
# [CV] END colsample_bytree=0.3, gamma=0.2, learning_rate=0.1, max_depth=6, min_child_weight=1, n_estimators=400, reg_alpha=0.5, reg_lambda=1; total time=   0.5s
# [CV] END colsample_bytree=0.3, gamma=0.2, learning_rate=0.1, max_depth=6, min_child_weight=1, n_estimators=400, reg_alpha=0.5, reg_lambda=1; total time=   0.5s
# [CV] END colsample_bytree=0.3, gamma=0.2, learning_rate=0.1, max_depth=6, min_child_weight=1, n_estimators=400, reg_alpha=0.5, reg_lambda=1; total time=   0.5s
# [CV] END colsample_bytree=0.3, gamma=0.2, learning_rate=0.1, max_depth=6, min_child_weight=1, n_estimators=400, reg_alpha=0.5, reg_lambda=1; total time=   0.5s
# [CV] END colsample_bytree=0.3, gamma=0.2, learning_rate=0.1, max_depth=6, min_child_weight=1, n_estimators=400, reg_alpha=0.5, reg_lambda=1; total time=   0.5s
# [CV] END colsample_bytree=0.3, gamma=0.2, learning_rate=0.1, max_depth=6, min_child_weight=1, n_estimators=400, reg_alpha=0.5, reg_lambda=1; total time=   0.5s
# [CV] END colsample_bytree=0.3, gamma=0.2, learning_rate=0.1, max_depth=6, min_child_weight=1, n_estimators=400, reg_alpha=0.5, reg_lambda=1; total time=   0.5s
# [CV] END colsample_bytree=0.4, gamma=0.0, learning_rate=0.2, max_depth=8, min_child_weight=1, n_estimators=500, reg_alpha=1, reg_lambda=0.5; total time=   0.4s
# [CV] END colsample_bytree=0.4, gamma=0.0, learning_rate=0.2, max_depth=8, min_child_weight=1, n_estimators=500, reg_alpha=1, reg_lambda=0.5; total time=   0.4s
# [CV] END colsample_bytree=0.3, gamma=0.2, learning_rate=0.1, max_depth=6, min_child_weight=1, n_estimators=400, reg_alpha=0.5, reg_lambda=1; total time=   0.5s
# [CV] END colsample_bytree=0.4, gamma=0.0, learning_rate=0.2, max_depth=8, min_child_weight=1, n_estimators=500, reg_alpha=1, reg_lambda=0.5; total time=   0.4s
# [CV] END colsample_bytree=0.4, gamma=0.0, learning_rate=0.2, max_depth=8, min_child_weight=1, n_estimators=500, reg_alpha=1, reg_lambda=0.5; total time=   0.4s
# [CV] END colsample_bytree=0.4, gamma=0.0, learning_rate=0.2, max_depth=8, min_child_weight=1, n_estimators=500, reg_alpha=1, reg_lambda=0.5; total time=   0.4s
# [CV] END colsample_bytree=0.4, gamma=0.0, learning_rate=0.2, max_depth=8, min_child_weight=1, n_estimators=500, reg_alpha=1, reg_lambda=0.5; total time=   0.6s
# [CV] END colsample_bytree=0.3, gamma=0.2, learning_rate=0.1, max_depth=6, min_child_weight=1, n_estimators=400, reg_alpha=0.5, reg_lambda=1; total time=   0.5s
# [CV] END colsample_bytree=0.4, gamma=0.0, learning_rate=0.2, max_depth=8, min_child_weight=1, n_estimators=500, reg_alpha=1, reg_lambda=0.5; total time=   0.4s
# [CV] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.15, max_depth=3, min_child_weight=7, n_estimators=300, reg_alpha=0, reg_lambda=1; total time=   0.3s
# [CV] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.15, max_depth=3, min_child_weight=7, n_estimators=300, reg_alpha=0, reg_lambda=1; total time=   0.3s
# [CV] END colsample_bytree=0.4, gamma=0.0, learning_rate=0.2, max_depth=8, min_child_weight=1, n_estimators=500, reg_alpha=1, reg_lambda=0.5; total time=   0.5s
# [CV] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.15, max_depth=3, min_child_weight=7, n_estimators=300, reg_alpha=0, reg_lambda=1; total time=   0.3s
# [CV] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.15, max_depth=3, min_child_weight=7, n_estimators=300, reg_alpha=0, reg_lambda=1; total time=   0.3s
# [CV] END colsample_bytree=0.4, gamma=0.0, learning_rate=0.2, max_depth=8, min_child_weight=1, n_estimators=500, reg_alpha=1, reg_lambda=0.5; total time=   0.4s
# [CV] END colsample_bytree=0.4, gamma=0.0, learning_rate=0.2, max_depth=8, min_child_weight=1, n_estimators=500, reg_alpha=1, reg_lambda=0.5; total time=   0.4s
# [CV] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.15, max_depth=3, min_child_weight=7, n_estimators=300, reg_alpha=0, reg_lambda=1; total time=   0.3s
# [CV] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.15, max_depth=3, min_child_weight=7, n_estimators=300, reg_alpha=0, reg_lambda=1; total time=   0.3s
# [CV] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.15, max_depth=3, min_child_weight=7, n_estimators=300, reg_alpha=0, reg_lambda=1; total time=   0.4s
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.2, max_depth=3, min_child_weight=5, n_estimators=200, reg_alpha=1, reg_lambda=1; total time=   0.2s
# [CV] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.15, max_depth=3, min_child_weight=7, n_estimators=300, reg_alpha=0, reg_lambda=1; total time=   0.3s
# [CV] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.15, max_depth=3, min_child_weight=7, n_estimators=300, reg_alpha=0, reg_lambda=1; total time=   0.3s
# [CV] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.15, max_depth=3, min_child_weight=7, n_estimators=300, reg_alpha=0, reg_lambda=1; total time=   0.3s
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.2, max_depth=3, min_child_weight=5, n_estimators=200, reg_alpha=1, reg_lambda=1; total time=   0.2s
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.2, max_depth=3, min_child_weight=5, n_estimators=200, reg_alpha=1, reg_lambda=1; total time=   0.2s
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.2, max_depth=3, min_child_weight=5, n_estimators=200, reg_alpha=1, reg_lambda=1; total time=   0.2s
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.2, max_depth=3, min_child_weight=5, n_estimators=200, reg_alpha=1, reg_lambda=1; total time=   0.2s
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.2, max_depth=3, min_child_weight=5, n_estimators=200, reg_alpha=1, reg_lambda=1; total time=   0.2s
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.2, max_depth=3, min_child_weight=5, n_estimators=200, reg_alpha=1, reg_lambda=1; total time=   0.2s
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.2, max_depth=3, min_child_weight=5, n_estimators=200, reg_alpha=1, reg_lambda=1; total time=   0.2s
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.2, max_depth=3, min_child_weight=5, n_estimators=200, reg_alpha=1, reg_lambda=1; total time=   0.2s
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.2, max_depth=3, min_child_weight=5, n_estimators=200, reg_alpha=1, reg_lambda=1; total time=   0.2s
# [CV] END colsample_bytree=0.3, gamma=0.3, learning_rate=0.2, max_depth=5, min_child_weight=7, n_estimators=200, reg_alpha=1, reg_lambda=1; total time=   0.2s
# [CV] END colsample_bytree=0.3, gamma=0.3, learning_rate=0.2, max_depth=5, min_child_weight=7, n_estimators=200, reg_alpha=1, reg_lambda=1; total time=   0.2s
# [CV] END colsample_bytree=0.3, gamma=0.3, learning_rate=0.2, max_depth=5, min_child_weight=7, n_estimators=200, reg_alpha=1, reg_lambda=1; total time=   0.2s
# [CV] END colsample_bytree=0.3, gamma=0.3, learning_rate=0.2, max_depth=5, min_child_weight=7, n_estimators=200, reg_alpha=1, reg_lambda=1; total time=   0.2s
# [CV] END colsample_bytree=0.3, gamma=0.3, learning_rate=0.2, max_depth=5, min_child_weight=7, n_estimators=200, reg_alpha=1, reg_lambda=1; total time=   0.2s
# [CV] END colsample_bytree=0.3, gamma=0.3, learning_rate=0.2, max_depth=5, min_child_weight=7, n_estimators=200, reg_alpha=1, reg_lambda=1; total time=   0.2s
# [CV] END colsample_bytree=0.3, gamma=0.3, learning_rate=0.2, max_depth=5, min_child_weight=7, n_estimators=200, reg_alpha=1, reg_lambda=1; total time=   0.2s
# [CV] END colsample_bytree=0.3, gamma=0.3, learning_rate=0.2, max_depth=5, min_child_weight=7, n_estimators=200, reg_alpha=1, reg_lambda=1; total time=   0.2s
# [CV] END colsample_bytree=0.3, gamma=0.3, learning_rate=0.2, max_depth=5, min_child_weight=7, n_estimators=200, reg_alpha=1, reg_lambda=1; total time=   0.2s
# [CV] END colsample_bytree=0.3, gamma=0.3, learning_rate=0.2, max_depth=5, min_child_weight=7, n_estimators=200, reg_alpha=1, reg_lambda=1; total time=   0.2s
# [CV] END colsample_bytree=0.7, gamma=0.0, learning_rate=0.1, max_depth=8, min_child_weight=1, n_estimators=300, reg_alpha=0.5, reg_lambda=5; total time=   0.8s
# [CV] END colsample_bytree=0.7, gamma=0.0, learning_rate=0.1, max_depth=8, min_child_weight=1, n_estimators=300, reg_alpha=0.5, reg_lambda=5; total time=   0.8s
# [CV] END colsample_bytree=0.7, gamma=0.0, learning_rate=0.1, max_depth=8, min_child_weight=1, n_estimators=300, reg_alpha=0.5, reg_lambda=5; total time=   0.8s
# [CV] END colsample_bytree=0.7, gamma=0.0, learning_rate=0.1, max_depth=8, min_child_weight=1, n_estimators=300, reg_alpha=0.5, reg_lambda=5; total time=   0.8s
# [CV] END colsample_bytree=0.7, gamma=0.0, learning_rate=0.1, max_depth=8, min_child_weight=1, n_estimators=300, reg_alpha=0.5, reg_lambda=5; total time=   0.7s
# [CV] END colsample_bytree=0.7, gamma=0.0, learning_rate=0.1, max_depth=8, min_child_weight=1, n_estimators=300, reg_alpha=0.5, reg_lambda=5; total time=   0.8s
# [CV] END colsample_bytree=0.7, gamma=0.0, learning_rate=0.1, max_depth=8, min_child_weight=1, n_estimators=300, reg_alpha=0.5, reg_lambda=5; total time=   0.7s
# [CV] END colsample_bytree=0.7, gamma=0.0, learning_rate=0.1, max_depth=8, min_child_weight=1, n_estimators=300, reg_alpha=0.5, reg_lambda=5; total time=   0.7s
# [CV] END colsample_bytree=0.7, gamma=0.0, learning_rate=0.25, max_depth=12, min_child_weight=5, n_estimators=500, reg_alpha=0.5, reg_lambda=0; total time=   0.6s
# [CV] END colsample_bytree=0.7, gamma=0.0, learning_rate=0.25, max_depth=12, min_child_weight=5, n_estimators=500, reg_alpha=0.5, reg_lambda=0; total time=   0.7s
# [CV] END colsample_bytree=0.7, gamma=0.0, learning_rate=0.1, max_depth=8, min_child_weight=1, n_estimators=300, reg_alpha=0.5, reg_lambda=5; total time=   0.8s
# [CV] END colsample_bytree=0.7, gamma=0.0, learning_rate=0.25, max_depth=12, min_child_weight=5, n_estimators=500, reg_alpha=0.5, reg_lambda=0; total time=   0.7s
# [CV] END colsample_bytree=0.7, gamma=0.0, learning_rate=0.25, max_depth=12, min_child_weight=5, n_estimators=500, reg_alpha=0.5, reg_lambda=0; total time=   0.6s
# [CV] END colsample_bytree=0.7, gamma=0.0, learning_rate=0.25, max_depth=12, min_child_weight=5, n_estimators=500, reg_alpha=0.5, reg_lambda=0; total time=   0.7s
# [CV] END colsample_bytree=0.7, gamma=0.0, learning_rate=0.25, max_depth=12, min_child_weight=5, n_estimators=500, reg_alpha=0.5, reg_lambda=0; total time=   0.7s
# [CV] END colsample_bytree=0.7, gamma=0.0, learning_rate=0.1, max_depth=8, min_child_weight=1, n_estimators=300, reg_alpha=0.5, reg_lambda=5; total time=   0.8s
# [CV] END colsample_bytree=0.7, gamma=0.0, learning_rate=0.25, max_depth=12, min_child_weight=5, n_estimators=500, reg_alpha=0.5, reg_lambda=0; total time=   0.6s
# [CV] END colsample_bytree=0.7, gamma=0.0, learning_rate=0.25, max_depth=12, min_child_weight=5, n_estimators=500, reg_alpha=0.5, reg_lambda=0; total time=   0.7s
# [CV] END colsample_bytree=0.4, gamma=0.2, learning_rate=0.05, max_depth=12, min_child_weight=1, n_estimators=400, reg_alpha=0, reg_lambda=5; total time=   1.0s
# [CV] END colsample_bytree=0.4, gamma=0.2, learning_rate=0.05, max_depth=12, min_child_weight=1, n_estimators=400, reg_alpha=0, reg_lambda=5; total time=   0.9s
# [CV] END colsample_bytree=0.7, gamma=0.0, learning_rate=0.25, max_depth=12, min_child_weight=5, n_estimators=500, reg_alpha=0.5, reg_lambda=0; total time=   0.7s
# [CV] END colsample_bytree=0.7, gamma=0.0, learning_rate=0.25, max_depth=12, min_child_weight=5, n_estimators=500, reg_alpha=0.5, reg_lambda=0; total time=   0.7s
# [CV] END colsample_bytree=0.4, gamma=0.2, learning_rate=0.05, max_depth=12, min_child_weight=1, n_estimators=400, reg_alpha=0, reg_lambda=5; total time=   0.9s
# [CV] END colsample_bytree=0.4, gamma=0.2, learning_rate=0.05, max_depth=12, min_child_weight=1, n_estimators=400, reg_alpha=0, reg_lambda=5; total time=   1.0s
# [CV] END colsample_bytree=0.4, gamma=0.2, learning_rate=0.05, max_depth=12, min_child_weight=1, n_estimators=400, reg_alpha=0, reg_lambda=5; total time=   0.9s
# [CV] END colsample_bytree=0.4, gamma=0.2, learning_rate=0.05, max_depth=12, min_child_weight=1, n_estimators=400, reg_alpha=0, reg_lambda=5; total time=   1.0s
# [CV] END colsample_bytree=0.4, gamma=0.2, learning_rate=0.05, max_depth=12, min_child_weight=1, n_estimators=400, reg_alpha=0, reg_lambda=5; total time=   0.9s
# [CV] END colsample_bytree=0.4, gamma=0.2, learning_rate=0.05, max_depth=12, min_child_weight=1, n_estimators=400, reg_alpha=0, reg_lambda=5; total time=   0.9s
# [CV] END colsample_bytree=0.4, gamma=0.2, learning_rate=0.05, max_depth=12, min_child_weight=1, n_estimators=400, reg_alpha=0, reg_lambda=5; total time=   1.0s
# [CV] END colsample_bytree=0.4, gamma=0.2, learning_rate=0.05, max_depth=12, min_child_weight=1, n_estimators=400, reg_alpha=0, reg_lambda=5; total time=   1.0s
# [CV] END colsample_bytree=0.4, gamma=0.2, learning_rate=0.25, max_depth=10, min_child_weight=5, n_estimators=400, reg_alpha=0.5, reg_lambda=5; total time=   0.7s
# [CV] END colsample_bytree=0.4, gamma=0.2, learning_rate=0.25, max_depth=10, min_child_weight=5, n_estimators=400, reg_alpha=0.5, reg_lambda=5; total time=   0.7s
# [CV] END colsample_bytree=0.4, gamma=0.2, learning_rate=0.25, max_depth=10, min_child_weight=5, n_estimators=400, reg_alpha=0.5, reg_lambda=5; total time=   0.7s
# [CV] END colsample_bytree=0.4, gamma=0.2, learning_rate=0.25, max_depth=10, min_child_weight=5, n_estimators=400, reg_alpha=0.5, reg_lambda=5; total time=   0.7s
# [CV] END colsample_bytree=0.4, gamma=0.2, learning_rate=0.25, max_depth=10, min_child_weight=5, n_estimators=400, reg_alpha=0.5, reg_lambda=5; total time=   0.7s
# [CV] END colsample_bytree=0.4, gamma=0.2, learning_rate=0.25, max_depth=10, min_child_weight=5, n_estimators=400, reg_alpha=0.5, reg_lambda=5; total time=   0.7s
# [CV] END colsample_bytree=0.4, gamma=0.2, learning_rate=0.25, max_depth=10, min_child_weight=5, n_estimators=400, reg_alpha=0.5, reg_lambda=5; total time=   0.7s
# [CV] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.1, max_depth=15, min_child_weight=3, n_estimators=20, reg_alpha=0.5, reg_lambda=5; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.1, max_depth=15, min_child_weight=3, n_estimators=20, reg_alpha=0.5, reg_lambda=5; total time=   0.0s
# [CV] END colsample_bytree=0.4, gamma=0.2, learning_rate=0.25, max_depth=10, min_child_weight=5, n_estimators=400, reg_alpha=0.5, reg_lambda=5; total time=   0.7s
# [CV] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.1, max_depth=15, min_child_weight=3, n_estimators=20, reg_alpha=0.5, reg_lambda=5; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.1, max_depth=15, min_child_weight=3, n_estimators=20, reg_alpha=0.5, reg_lambda=5; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.1, max_depth=15, min_child_weight=3, n_estimators=20, reg_alpha=0.5, reg_lambda=5; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.1, max_depth=15, min_child_weight=3, n_estimators=20, reg_alpha=0.5, reg_lambda=5; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.1, max_depth=15, min_child_weight=3, n_estimators=20, reg_alpha=0.5, reg_lambda=5; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.1, max_depth=15, min_child_weight=3, n_estimators=20, reg_alpha=0.5, reg_lambda=5; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.1, max_depth=15, min_child_weight=3, n_estimators=20, reg_alpha=0.5, reg_lambda=5; total time=   0.0s
# [CV] END colsample_bytree=0.3, gamma=0.1, learning_rate=0.25, max_depth=3, min_child_weight=3, n_estimators=10, reg_alpha=0, reg_lambda=1; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.1, max_depth=15, min_child_weight=3, n_estimators=20, reg_alpha=0.5, reg_lambda=5; total time=   0.0s
# [CV] END colsample_bytree=0.3, gamma=0.1, learning_rate=0.25, max_depth=3, min_child_weight=3, n_estimators=10, reg_alpha=0, reg_lambda=1; total time=   0.0s
# [CV] END colsample_bytree=0.3, gamma=0.1, learning_rate=0.25, max_depth=3, min_child_weight=3, n_estimators=10, reg_alpha=0, reg_lambda=1; total time=   0.0s
# [CV] END colsample_bytree=0.3, gamma=0.1, learning_rate=0.25, max_depth=3, min_child_weight=3, n_estimators=10, reg_alpha=0, reg_lambda=1; total time=   0.0s
# [CV] END colsample_bytree=0.3, gamma=0.1, learning_rate=0.25, max_depth=3, min_child_weight=3, n_estimators=10, reg_alpha=0, reg_lambda=1; total time=   0.0s
# [CV] END colsample_bytree=0.3, gamma=0.1, learning_rate=0.25, max_depth=3, min_child_weight=3, n_estimators=10, reg_alpha=0, reg_lambda=1; total time=   0.0s
# [CV] END colsample_bytree=0.3, gamma=0.1, learning_rate=0.25, max_depth=3, min_child_weight=3, n_estimators=10, reg_alpha=0, reg_lambda=1; total time=   0.0s
# [CV] END colsample_bytree=0.3, gamma=0.1, learning_rate=0.25, max_depth=3, min_child_weight=3, n_estimators=10, reg_alpha=0, reg_lambda=1; total time=   0.0s
# [CV] END colsample_bytree=0.3, gamma=0.1, learning_rate=0.25, max_depth=3, min_child_weight=3, n_estimators=10, reg_alpha=0, reg_lambda=1; total time=   0.0s
# [CV] END colsample_bytree=0.3, gamma=0.1, learning_rate=0.25, max_depth=3, min_child_weight=3, n_estimators=10, reg_alpha=0, reg_lambda=1; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=0.3, learning_rate=0.15, max_depth=6, min_child_weight=3, n_estimators=20, reg_alpha=0.5, reg_lambda=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=0.3, learning_rate=0.15, max_depth=6, min_child_weight=3, n_estimators=20, reg_alpha=0.5, reg_lambda=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=0.3, learning_rate=0.15, max_depth=6, min_child_weight=3, n_estimators=20, reg_alpha=0.5, reg_lambda=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=0.3, learning_rate=0.15, max_depth=6, min_child_weight=3, n_estimators=20, reg_alpha=0.5, reg_lambda=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=0.3, learning_rate=0.15, max_depth=6, min_child_weight=3, n_estimators=20, reg_alpha=0.5, reg_lambda=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=0.3, learning_rate=0.15, max_depth=6, min_child_weight=3, n_estimators=20, reg_alpha=0.5, reg_lambda=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=0.3, learning_rate=0.15, max_depth=6, min_child_weight=3, n_estimators=20, reg_alpha=0.5, reg_lambda=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=0.3, learning_rate=0.15, max_depth=6, min_child_weight=3, n_estimators=20, reg_alpha=0.5, reg_lambda=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=0.3, learning_rate=0.15, max_depth=6, min_child_weight=3, n_estimators=20, reg_alpha=0.5, reg_lambda=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.4, gamma=0.2, learning_rate=0.25, max_depth=10, min_child_weight=5, n_estimators=400, reg_alpha=0.5, reg_lambda=5; total time=   0.7s
# [CV] END colsample_bytree=0.5, gamma=0.3, learning_rate=0.15, max_depth=6, min_child_weight=3, n_estimators=20, reg_alpha=0.5, reg_lambda=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.4, gamma=0.2, learning_rate=0.25, max_depth=10, min_child_weight=5, n_estimators=400, reg_alpha=0.5, reg_lambda=5; total time=   0.7s
# [CV] END colsample_bytree=0.3, gamma=0.2, learning_rate=0.2, max_depth=12, min_child_weight=5, n_estimators=100, reg_alpha=0.5, reg_lambda=0; total time=   0.2s
# [CV] END colsample_bytree=0.3, gamma=0.2, learning_rate=0.2, max_depth=12, min_child_weight=5, n_estimators=100, reg_alpha=0.5, reg_lambda=0; total time=   0.2s
# [CV] END colsample_bytree=0.3, gamma=0.2, learning_rate=0.2, max_depth=12, min_child_weight=5, n_estimators=100, reg_alpha=0.5, reg_lambda=0; total time=   0.2s
# [CV] END colsample_bytree=0.3, gamma=0.2, learning_rate=0.2, max_depth=12, min_child_weight=5, n_estimators=100, reg_alpha=0.5, reg_lambda=0; total time=   0.2s
# [CV] END colsample_bytree=0.3, gamma=0.2, learning_rate=0.2, max_depth=12, min_child_weight=5, n_estimators=100, reg_alpha=0.5, reg_lambda=0; total time=   0.2s
# [CV] END colsample_bytree=0.3, gamma=0.2, learning_rate=0.2, max_depth=12, min_child_weight=5, n_estimators=100, reg_alpha=0.5, reg_lambda=0; total time=   0.2s
# [CV] END colsample_bytree=0.5, gamma=0.0, learning_rate=0.25, max_depth=4, min_child_weight=5, n_estimators=10, reg_alpha=0, reg_lambda=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.3, gamma=0.2, learning_rate=0.2, max_depth=12, min_child_weight=5, n_estimators=100, reg_alpha=0.5, reg_lambda=0; total time=   0.2s
# [CV] END colsample_bytree=0.3, gamma=0.2, learning_rate=0.2, max_depth=12, min_child_weight=5, n_estimators=100, reg_alpha=0.5, reg_lambda=0; total time=   0.2s
# [CV] END colsample_bytree=0.5, gamma=0.0, learning_rate=0.25, max_depth=4, min_child_weight=5, n_estimators=10, reg_alpha=0, reg_lambda=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=0.0, learning_rate=0.25, max_depth=4, min_child_weight=5, n_estimators=10, reg_alpha=0, reg_lambda=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=0.0, learning_rate=0.25, max_depth=4, min_child_weight=5, n_estimators=10, reg_alpha=0, reg_lambda=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=0.0, learning_rate=0.25, max_depth=4, min_child_weight=5, n_estimators=10, reg_alpha=0, reg_lambda=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=0.0, learning_rate=0.25, max_depth=4, min_child_weight=5, n_estimators=10, reg_alpha=0, reg_lambda=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=0.0, learning_rate=0.25, max_depth=4, min_child_weight=5, n_estimators=10, reg_alpha=0, reg_lambda=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=0.0, learning_rate=0.25, max_depth=4, min_child_weight=5, n_estimators=10, reg_alpha=0, reg_lambda=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.3, gamma=0.2, learning_rate=0.2, max_depth=12, min_child_weight=5, n_estimators=100, reg_alpha=0.5, reg_lambda=0; total time=   0.2s
# [CV] END colsample_bytree=0.3, gamma=0.2, learning_rate=0.2, max_depth=12, min_child_weight=5, n_estimators=100, reg_alpha=0.5, reg_lambda=0; total time=   0.2s
# [CV] END colsample_bytree=0.5, gamma=0.0, learning_rate=0.25, max_depth=4, min_child_weight=5, n_estimators=10, reg_alpha=0, reg_lambda=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=0.0, learning_rate=0.25, max_depth=4, min_child_weight=5, n_estimators=10, reg_alpha=0, reg_lambda=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=0.3, learning_rate=0.05, max_depth=8, min_child_weight=5, n_estimators=300, reg_alpha=0.5, reg_lambda=5; total time=   0.5s
# [CV] END colsample_bytree=0.5, gamma=0.3, learning_rate=0.05, max_depth=8, min_child_weight=5, n_estimators=300, reg_alpha=0.5, reg_lambda=5; total time=   0.5s
# [CV] END colsample_bytree=0.5, gamma=0.3, learning_rate=0.05, max_depth=8, min_child_weight=5, n_estimators=300, reg_alpha=0.5, reg_lambda=5; total time=   0.5s
# [CV] END colsample_bytree=0.4, gamma=0.2, learning_rate=0.3, max_depth=5, min_child_weight=7, n_estimators=400, reg_alpha=1, reg_lambda=5; total time=   0.5s
# [CV] END colsample_bytree=0.5, gamma=0.3, learning_rate=0.05, max_depth=8, min_child_weight=5, n_estimators=300, reg_alpha=0.5, reg_lambda=5; total time=   0.5s
# [CV] END colsample_bytree=0.5, gamma=0.3, learning_rate=0.05, max_depth=8, min_child_weight=5, n_estimators=300, reg_alpha=0.5, reg_lambda=5; total time=   0.5s
# [CV] END colsample_bytree=0.5, gamma=0.3, learning_rate=0.05, max_depth=8, min_child_weight=5, n_estimators=300, reg_alpha=0.5, reg_lambda=5; total time=   0.5s
# [CV] END colsample_bytree=0.4, gamma=0.2, learning_rate=0.3, max_depth=5, min_child_weight=7, n_estimators=400, reg_alpha=1, reg_lambda=5; total time=   0.5s
# [CV] END colsample_bytree=0.5, gamma=0.3, learning_rate=0.05, max_depth=8, min_child_weight=5, n_estimators=300, reg_alpha=0.5, reg_lambda=5; total time=   0.5s
# [CV] END colsample_bytree=0.5, gamma=0.3, learning_rate=0.05, max_depth=8, min_child_weight=5, n_estimators=300, reg_alpha=0.5, reg_lambda=5; total time=   0.5s
# [CV] END colsample_bytree=0.4, gamma=0.2, learning_rate=0.3, max_depth=5, min_child_weight=7, n_estimators=400, reg_alpha=1, reg_lambda=5; total time=   0.5s
# [CV] END colsample_bytree=0.4, gamma=0.2, learning_rate=0.3, max_depth=5, min_child_weight=7, n_estimators=400, reg_alpha=1, reg_lambda=5; total time=   0.5s
# [CV] END colsample_bytree=0.5, gamma=0.3, learning_rate=0.05, max_depth=8, min_child_weight=5, n_estimators=300, reg_alpha=0.5, reg_lambda=5; total time=   0.5s
# [CV] END colsample_bytree=0.4, gamma=0.2, learning_rate=0.3, max_depth=5, min_child_weight=7, n_estimators=400, reg_alpha=1, reg_lambda=5; total time=   0.5s
# [CV] END colsample_bytree=0.5, gamma=0.3, learning_rate=0.05, max_depth=8, min_child_weight=5, n_estimators=300, reg_alpha=0.5, reg_lambda=5; total time=   0.5s
# [CV] END colsample_bytree=0.5, gamma=0.3, learning_rate=0.1, max_depth=12, min_child_weight=7, n_estimators=20, reg_alpha=5, reg_lambda=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=0.3, learning_rate=0.1, max_depth=12, min_child_weight=7, n_estimators=20, reg_alpha=5, reg_lambda=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=0.3, learning_rate=0.1, max_depth=12, min_child_weight=7, n_estimators=20, reg_alpha=5, reg_lambda=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.5, gamma=0.3, learning_rate=0.1, max_depth=12, min_child_weight=7, n_estimators=20, reg_alpha=5, reg_lambda=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.5, gamma=0.3, learning_rate=0.1, max_depth=12, min_child_weight=7, n_estimators=20, reg_alpha=5, reg_lambda=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=0.3, learning_rate=0.1, max_depth=12, min_child_weight=7, n_estimators=20, reg_alpha=5, reg_lambda=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=0.3, learning_rate=0.1, max_depth=12, min_child_weight=7, n_estimators=20, reg_alpha=5, reg_lambda=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=0.3, learning_rate=0.1, max_depth=12, min_child_weight=7, n_estimators=20, reg_alpha=5, reg_lambda=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.4, gamma=0.2, learning_rate=0.3, max_depth=5, min_child_weight=7, n_estimators=400, reg_alpha=1, reg_lambda=5; total time=   0.5s
# [CV] END colsample_bytree=0.5, gamma=0.3, learning_rate=0.1, max_depth=12, min_child_weight=7, n_estimators=20, reg_alpha=5, reg_lambda=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.5, gamma=0.3, learning_rate=0.1, max_depth=12, min_child_weight=7, n_estimators=20, reg_alpha=5, reg_lambda=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=0.0, learning_rate=0.1, max_depth=10, min_child_weight=5, n_estimators=50, reg_alpha=0.5, reg_lambda=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.5, gamma=0.0, learning_rate=0.1, max_depth=10, min_child_weight=5, n_estimators=50, reg_alpha=0.5, reg_lambda=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.5, gamma=0.0, learning_rate=0.1, max_depth=10, min_child_weight=5, n_estimators=50, reg_alpha=0.5, reg_lambda=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.5, gamma=0.0, learning_rate=0.1, max_depth=10, min_child_weight=5, n_estimators=50, reg_alpha=0.5, reg_lambda=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.5, gamma=0.0, learning_rate=0.1, max_depth=10, min_child_weight=5, n_estimators=50, reg_alpha=0.5, reg_lambda=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.4, gamma=0.2, learning_rate=0.3, max_depth=5, min_child_weight=7, n_estimators=400, reg_alpha=1, reg_lambda=5; total time=   0.5s
# [CV] END colsample_bytree=0.5, gamma=0.0, learning_rate=0.1, max_depth=10, min_child_weight=5, n_estimators=50, reg_alpha=0.5, reg_lambda=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.4, gamma=0.3, learning_rate=0.05, max_depth=8, min_child_weight=7, n_estimators=10, reg_alpha=0, reg_lambda=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=0.0, learning_rate=0.1, max_depth=10, min_child_weight=5, n_estimators=50, reg_alpha=0.5, reg_lambda=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.4, gamma=0.3, learning_rate=0.05, max_depth=8, min_child_weight=7, n_estimators=10, reg_alpha=0, reg_lambda=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=0.0, learning_rate=0.1, max_depth=10, min_child_weight=5, n_estimators=50, reg_alpha=0.5, reg_lambda=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.4, gamma=0.3, learning_rate=0.05, max_depth=8, min_child_weight=7, n_estimators=10, reg_alpha=0, reg_lambda=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.4, gamma=0.3, learning_rate=0.05, max_depth=8, min_child_weight=7, n_estimators=10, reg_alpha=0, reg_lambda=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.4, gamma=0.3, learning_rate=0.05, max_depth=8, min_child_weight=7, n_estimators=10, reg_alpha=0, reg_lambda=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.4, gamma=0.3, learning_rate=0.05, max_depth=8, min_child_weight=7, n_estimators=10, reg_alpha=0, reg_lambda=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=0.0, learning_rate=0.1, max_depth=10, min_child_weight=5, n_estimators=50, reg_alpha=0.5, reg_lambda=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.4, gamma=0.3, learning_rate=0.05, max_depth=8, min_child_weight=7, n_estimators=10, reg_alpha=0, reg_lambda=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.4, gamma=0.3, learning_rate=0.05, max_depth=8, min_child_weight=7, n_estimators=10, reg_alpha=0, reg_lambda=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=0.0, learning_rate=0.1, max_depth=10, min_child_weight=5, n_estimators=50, reg_alpha=0.5, reg_lambda=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.4, gamma=0.3, learning_rate=0.05, max_depth=8, min_child_weight=7, n_estimators=10, reg_alpha=0, reg_lambda=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.4, gamma=0.3, learning_rate=0.05, max_depth=8, min_child_weight=7, n_estimators=10, reg_alpha=0, reg_lambda=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=0.0, learning_rate=0.3, max_depth=5, min_child_weight=3, n_estimators=100, reg_alpha=5, reg_lambda=5; total time=   0.1s
# [CV] END colsample_bytree=0.5, gamma=0.0, learning_rate=0.3, max_depth=5, min_child_weight=3, n_estimators=100, reg_alpha=5, reg_lambda=5; total time=   0.1s
# [CV] END colsample_bytree=0.5, gamma=0.0, learning_rate=0.3, max_depth=5, min_child_weight=3, n_estimators=100, reg_alpha=5, reg_lambda=5; total time=   0.1s
# [CV] END colsample_bytree=0.5, gamma=0.0, learning_rate=0.3, max_depth=5, min_child_weight=3, n_estimators=100, reg_alpha=5, reg_lambda=5; total time=   0.2s
# [CV] END colsample_bytree=0.4, gamma=0.2, learning_rate=0.3, max_depth=5, min_child_weight=7, n_estimators=400, reg_alpha=1, reg_lambda=5; total time=   0.5s
# [CV] END colsample_bytree=0.5, gamma=0.0, learning_rate=0.3, max_depth=5, min_child_weight=3, n_estimators=100, reg_alpha=5, reg_lambda=5; total time=   0.1s
# [CV] END colsample_bytree=0.5, gamma=0.0, learning_rate=0.3, max_depth=5, min_child_weight=3, n_estimators=100, reg_alpha=5, reg_lambda=5; total time=   0.2s
# [CV] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.1, max_depth=4, min_child_weight=7, n_estimators=100, reg_alpha=1, reg_lambda=5; total time=   0.1s
# [CV] END colsample_bytree=0.5, gamma=0.0, learning_rate=0.3, max_depth=5, min_child_weight=3, n_estimators=100, reg_alpha=5, reg_lambda=5; total time=   0.2s
# [CV] END colsample_bytree=0.5, gamma=0.0, learning_rate=0.3, max_depth=5, min_child_weight=3, n_estimators=100, reg_alpha=5, reg_lambda=5; total time=   0.2s
# [CV] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.1, max_depth=4, min_child_weight=7, n_estimators=100, reg_alpha=1, reg_lambda=5; total time=   0.1s
# [CV] END colsample_bytree=0.5, gamma=0.0, learning_rate=0.3, max_depth=5, min_child_weight=3, n_estimators=100, reg_alpha=5, reg_lambda=5; total time=   0.1s
# [CV] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.1, max_depth=4, min_child_weight=7, n_estimators=100, reg_alpha=1, reg_lambda=5; total time=   0.1s
# [CV] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.1, max_depth=4, min_child_weight=7, n_estimators=100, reg_alpha=1, reg_lambda=5; total time=   0.1s
# [CV] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.1, max_depth=4, min_child_weight=7, n_estimators=100, reg_alpha=1, reg_lambda=5; total time=   0.1s
# [CV] END colsample_bytree=0.4, gamma=0.2, learning_rate=0.3, max_depth=5, min_child_weight=7, n_estimators=400, reg_alpha=1, reg_lambda=5; total time=   0.5s
# [CV] END colsample_bytree=0.5, gamma=0.0, learning_rate=0.3, max_depth=5, min_child_weight=3, n_estimators=100, reg_alpha=5, reg_lambda=5; total time=   0.3s
# [CV] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.1, max_depth=4, min_child_weight=7, n_estimators=100, reg_alpha=1, reg_lambda=5; total time=   0.1s
# [CV] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.1, max_depth=4, min_child_weight=7, n_estimators=100, reg_alpha=1, reg_lambda=5; total time=   0.1s
# [CV] END colsample_bytree=0.4, gamma=0.4, learning_rate=0.2, max_depth=8, min_child_weight=5, n_estimators=20, reg_alpha=0.5, reg_lambda=0; total time=   0.0s
# [CV] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.1, max_depth=4, min_child_weight=7, n_estimators=100, reg_alpha=1, reg_lambda=5; total time=   0.1s
# [CV] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.1, max_depth=4, min_child_weight=7, n_estimators=100, reg_alpha=1, reg_lambda=5; total time=   0.1s
# [CV] END colsample_bytree=0.4, gamma=0.4, learning_rate=0.2, max_depth=8, min_child_weight=5, n_estimators=20, reg_alpha=0.5, reg_lambda=0; total time=   0.0s
# [CV] END colsample_bytree=0.4, gamma=0.4, learning_rate=0.2, max_depth=8, min_child_weight=5, n_estimators=20, reg_alpha=0.5, reg_lambda=0; total time=   0.0s
# [CV] END colsample_bytree=0.4, gamma=0.4, learning_rate=0.2, max_depth=8, min_child_weight=5, n_estimators=20, reg_alpha=0.5, reg_lambda=0; total time=   0.2s
# [CV] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.1, max_depth=4, min_child_weight=7, n_estimators=100, reg_alpha=1, reg_lambda=5; total time=   0.3s
# [CV] END colsample_bytree=0.4, gamma=0.4, learning_rate=0.2, max_depth=8, min_child_weight=5, n_estimators=20, reg_alpha=0.5, reg_lambda=0; total time=   0.1s
# [CV] END colsample_bytree=0.4, gamma=0.4, learning_rate=0.2, max_depth=8, min_child_weight=5, n_estimators=20, reg_alpha=0.5, reg_lambda=0; total time=   0.1s
# [CV] END colsample_bytree=0.4, gamma=0.4, learning_rate=0.2, max_depth=8, min_child_weight=5, n_estimators=20, reg_alpha=0.5, reg_lambda=0; total time=   0.0s
# [CV] END colsample_bytree=0.4, gamma=0.4, learning_rate=0.2, max_depth=8, min_child_weight=5, n_estimators=20, reg_alpha=0.5, reg_lambda=0; total time=   0.0s
# [CV] END colsample_bytree=0.4, gamma=0.4, learning_rate=0.2, max_depth=8, min_child_weight=5, n_estimators=20, reg_alpha=0.5, reg_lambda=0; total time=   0.0s
# [CV] END colsample_bytree=0.4, gamma=0.4, learning_rate=0.2, max_depth=8, min_child_weight=5, n_estimators=20, reg_alpha=0.5, reg_lambda=0; total time=   0.0s
# [CV] END colsample_bytree=0.4, gamma=0.2, learning_rate=0.3, max_depth=5, min_child_weight=7, n_estimators=400, reg_alpha=1, reg_lambda=5; total time=   0.6s
# RandomizedSearchCV(cv=10,
#                    estimator=XGBRegressor(base_score=None, booster=None,
#                                           callbacks=None,
#                                           colsample_bylevel=None,
#                                           colsample_bynode=None,
#                                           colsample_bytree=None,
#                                           early_stopping_rounds=None,
#                                           enable_categorical=False,
#                                           eval_metric=None, feature_types=None,
#                                           gamma=None, gpu_id=None,
#                                           grow_policy=None,
#                                           importance_type=None,
#                                           interaction_constraints=None,
#                                           learning_rate...
#                                           predictor=None, random_state=None, ...),
#                    n_iter=30, n_jobs=-1,
#                    param_distributions={'colsample_bytree': [0.3, 0.4, 0.5,
#                                                              0.7],
#                                         'gamma': [0.0, 0.1, 0.2, 0.3, 0.4],
#                                         'learning_rate': [0.05, 0.1, 0.15, 0.2,
#                                                           0.25, 0.3],
#                                         'max_depth': [3, 4, 5, 6, 8, 10, 12,
#                                                       15],
#                                         'min_child_weight': [1, 3, 5, 7],
#                                         'n_estimators': [10, 20, 50, 100, 200,
#                                                          300, 400, 500],
#                                         'reg_alpha': [0, 0.5, 1, 5],
#                                         'reg_lambda': [0, 0.5, 1, 5]},
#                    random_state=42, verbose=2)

# %%
reg_xgb = xgb.XGBRegressor(objective='reg:squarederror', missing=np.nan, seed=42, **xgbr_random.best_params_)
reg_xgb.fit(X_train, y_train)
evaluate(reg_xgb, X_test, y_test)
print(xgbr_random.best_params_)
# Out:
# RMSE: 36.201
# R^2: -0.242
# MAE: 25.868
# MAPE: 0.174
# Accuracy: 0.826
# {'reg_lambda': 0.5, 'reg_alpha': 0.5, 'n_estimators': 50, 'min_child_weight': 5, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 0.0, 'colsample_bytree': 0.5}

# %%
import matplotlib.pyplot as plt
import seaborn as sns

from matplotlib.ticker import StrMethodFormatter

ax = sns.scatterplot(x=y_test, y=reg_xgb.predict(X_test), color = '#86bf91')

ax.plot(y_test, y_test, color="red")

# Remove title
ax.set_title("Predicted vs Actual Rent Price", weight='bold', size=14)
ax.tick_params(axis='x', labelsize=12)
ax.tick_params(axis='y', labelsize=12)

# Set x-axis label
ax.set_xlabel("Actual", labelpad=20, weight='bold', size=12)

# Set y-axis label
ax.set_ylabel("Predicted", labelpad=20, weight='bold', size=12)

# Format y-axis label
ax.yaxis.set_major_formatter(StrMethodFormatter('{x:,g}'))

#set background to white
ax.set_facecolor('white')

# set bottom spin to black thin line
ax.spines['bottom'].set_visible(True)
ax.spines['bottom'].set_color('black')
ax.spines['bottom'].set_linewidth(0.8)

# Draw horizontal axis lines behind bars
vals = ax.get_yticks()
for tick in vals:
        
        ax.axhline(y=tick, linestyle='dashed', alpha=0.1, color='#eeeeee', zorder=1)

# %% [markdown]
# # XAI with SHAP

# %%
import seaborn as sns
import shap

shap.initjs()
# Out:
# IProgress not found. Please update jupyter and ipywidgets. See https://ipywidgets.readthedocs.io/en/stable/user_install.html
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %%
# create dataframe with 3 columns: y_pred, y_test, and absolute error
df = pd.DataFrame({'y_pred': reg_xgb.predict(X_test), 'y_test': y_test, 'abs_error': abs(reg_xgb.predict(X_test) - y_test)})

# reset index
df.reset_index(inplace=True, drop=True)

# sort dataframe by absolute error
df.sort_values(by=['abs_error'], ascending=False, inplace=True)

df
# Out:
#         y_pred      y_test   abs_error
# 29  197.677963   95.000000  102.677963
# 18  180.849030  274.000000   93.150970
# 6   199.269073  125.000000   74.269073
# 10  193.274277  139.000000   54.274277
# 11  173.596329  219.000000   45.403671
# 20  146.937958  186.838214   39.900256
# 24  186.217712  148.000000   38.217712
# 2   160.932922  127.000000   33.932922
# 12  138.909424  172.000000   33.090576
# 7   136.389099  167.000000   30.610901
# 17  177.919571  148.000000   29.919571
# 3   160.332260  187.000000   26.667740
# 13  150.086807  127.000000   23.086807
# 30  167.551025  188.000000   20.448975
# 19  122.769730  143.000000   20.230270
# 28  168.148102  148.000000   20.148102
# 16  191.954391  174.638528   17.315863
# 22  125.143456  139.000000   13.856544
# 15  138.404663  150.000000   11.595337
# 26  178.572968  190.000000   11.427032
# 5   164.579224  154.000000   10.579224
# 9   163.444183  153.000000   10.444183
# 14  187.900970  178.000000    9.900970
# 25  131.619263  122.000000    9.619263
# 1   160.955048  168.000000    7.044952
# 4   133.703293  140.000000    6.296707
# 0   154.793091  152.000000    2.793091
# 21  159.322250  157.000000    2.322250
# 27  157.618530  156.000000    1.618530
# 8   190.161362  191.000000    0.838638
# 23  156.779755  157.000000    0.220245

# %%
#explainer = shap.TreeExplainer(regressor_rf)
explainer = shap.TreeExplainer(reg_xgb)
shap_values = explainer(X_test)

# %%
shap.plots.bar(shap_values, max_display=6)

# %%
# Force plot of prediction with the highest error
shap.plots.force(shap_values[df.index[0]])
# Out:
# <div id='iIOXK3LDPMM1DFBGWO25W'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 163.25086975097656, "outValue": 197.677978515625, "link": "identity", "featureNames": ["GLA", "n_res_benefits", "population", "d_school", "d_transfer", "d_mainstreet", "n_business", "n_earners", "d_supermarket", "avg_income", "%_single_family_homes", "k20_high_income", "households_with_children", "single_households", "household_size", "k40_low_income", "WOZ", "n_owner_occupied", "urbanity_score", "supermarket_1km", "k0_k15", "k15_k25", "k25_k45", "k45_k65", "k65+"], "features": {"0": {"effect": 2.092275381088257, "value": 850.0}, "1": {"effect": 1.7025569677352905, "value": 1740.0}, "2": {"effect": 0.14152459800243